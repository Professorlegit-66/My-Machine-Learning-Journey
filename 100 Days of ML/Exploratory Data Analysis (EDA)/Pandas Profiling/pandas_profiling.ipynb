# %%
import pandas as pd
from data_profiling import ProfileReport

# %%
df = pd.read_csv('D:/Important Files/Machine Learning/Datasets/Books.csv')
df.head()
# Out:
#   category                                              title  rating  price  \
# 0   Travel                            It's Only the Himalayas       2  45.17
# 1   Travel  Full Moon over Noah’s Ark: An Odyssey to Mount...       4  49.43
# 2   Travel  See America: A Celebration of Our National Par...       3  48.87
# 3   Travel  Vagabonding: An Uncommon Guide to the Art of L...       2  36.94
# 4   Travel                               Under the Tuscan Sun       3  37.33
#
#       stock
# 0  In stock
# 1  In stock
# 2  In stock
# 3  In stock
# 4  In stock

# %%
profile = ProfileReport(df)
profile.to_file("report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
