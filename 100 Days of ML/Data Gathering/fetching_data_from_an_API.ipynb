# %%
import pandas as pd
import requests

# %% [markdown]
# # Making Weather Dataset

# %%
api_key = "781dd18326b26dc940f9fc29a3c43d94"

cities = ["Islamabad","Karachi","Lahore","Peshawar","Quetta","Faisalabad","Multan","Hyderabad","Sialkot","Gujranwala"]
rows = []

for city in cities:
    response = requests.get(f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={api_key}")
    data = response.json()
    rows.append({
        "City": city,
        "Temperature": data["main"]["temp"],
        "Humidity": data["main"]["humidity"],
        "Pressure": data["main"]["pressure"],
        "Wind Speed": data["wind"]["speed"],
        "Weather": data["weather"][0]["main"]
    })

df = pd.DataFrame(rows)

# %%
pd.DataFrame(df)
# Out:
#          City  Temperature  Humidity  Pressure  Wind Speed Weather
# 0   Islamabad       305.84        67      1004        0.79    Rain
# 1     Karachi       303.50        66      1003        6.79  Clouds
# 2      Lahore       313.53        32      1000        0.64  Clouds
# 3    Peshawar       308.75        43      1000        2.63   Clear
# 4      Quetta       306.11        11      1005        3.36  Clouds
# 5  Faisalabad       314.44        29       999        2.19  Clouds
# 6      Multan       314.46        30       999        3.76  Clouds
# 7   Hyderabad       303.20        59      1007        6.49    Rain
# 8     Sialkot       311.30        39      1000        2.51  Clouds
# 9  Gujranwala       313.43        34       999        0.15  Clouds

# %%
df.to_csv('Pakistan_Weather.csv')

# %% [markdown]
# # Making Country Dataset

# %%
response = requests.get(
  'https://api.restcountries.com/countries/v5?q=canada',
  headers={'Authorization': 'Bearer rc_live_43b41c1676034c90ad414a59faf25736'})
print(response.status_code)
print(response.json())
# Out:
# 200
# ...

# %%
data = response.json()["data"]["objects"]
df = pd.json_normalize(data)
df.head()
# Out:
#                                             capitals    region      subregion  \
# 0  [{'attributes': {'administrative': False, 'con...  Americas  North America
#
#   assets borders calling_codes       continents  \
# 0     []   [USA]           [1]  [North America]
#
#                                           currencies  \
# 0  [{'code': 'CAD', 'name': 'Canadian dollar', 's...
#
#                                  government_type  landlocked  ...  \
# 0  Federal parliamentary constitutional monarchy       False  ...
#
#   memberships.un number_format.decimal_separator  \
# 0           True                               .
#
#    number_format.thousands_separator parent.alpha_2 parent.alpha_3  \
# 0                                  ,
#
#   postal_code.format                                  postal_code.regex  \
# 0            @#@ #@#  ^([ABCEGHJKLMNPRSTVXY]\d[ABCEGHJKLMNPRSTVWXYZ]...
#
#   units.measurement_system units.temperature_scale _meta.lastUpdatedTimestamp
# ...

# %%
df[['continents','region','subregion','borders','currencies','government_type','capitals','landlocked']]
# Out:
#         continents    region      subregion borders  \
# 0  [North America]  Americas  North America   [USA]
#
#                                           currencies  \
# 0  [{'code': 'CAD', 'name': 'Canadian dollar', 's...
#
#                                  government_type  \
# 0  Federal parliamentary constitutional monarchy
#
#                                             capitals  landlocked
# 0  [{'attributes': {'administrative': False, 'con...       False

# %% [markdown]
# There are many list of dictionaries so we have to simplify it first

# %%
clean_df = pd.DataFrame({
    "Country": df["names.common"],
    "Region": df["region"],
    "Subregion": df["subregion"],
    "Capital": df["capitals"].str[0].str["name"],
    "Currency": df["currencies"].str[0].str["name"],
    "Currency Code": df["currencies"].str[0].str["code"],
    "Population": df["population"],
    "Continent": df["continents"].str[0],
    "Landlocked": df["landlocked"]
})

clean_df
# Out:
#   Country    Region      Subregion Capital         Currency Currency Code  \
# 0  Canada  Americas  North America  Ottawa  Canadian dollar           CAD
#
#    Population      Continent  Landlocked
# 0    41417056  North America       False

# %%
clean_df.to_csv('Countries_Details.csv')
