# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('D:/Important Files/Machine Learning/Datasets/train.csv',usecols=['Cabin'])
df.head()
# Out:
#   Cabin
# 0   NaN
# 1   C85
# 2   NaN
# 3  C123
# 4   NaN

# %%
df.fillna(df.mode().iloc[0], inplace=True)
df.head()
# Out:
#      Cabin
# 0  B96 B98
# 1      C85
# 2  B96 B98
# 3     C123
# 4  B96 B98

# %%
df['cabin_num'] = df['Cabin'].str.extract(r'(\d+)')
df['cabin_cat'] = df['Cabin'].str[0]

# %%
df.head()
# Out:
#      Cabin cabin_num cabin_cat
# 0  B96 B98        96         B
# 1      C85        85         C
# 2  B96 B98        96         B
# 3     C123       123         C
# 4  B96 B98        96         B

# %%
df['cabin_cat'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='cabin_cat'>

# %%
# This is for the data column if it has separate numerical and categorical parts like numerical part 
# in separate rows and categorical part in separate rows unlike the cabin column.

# df['numerical_column'] = pd.to_numeric(df['Cabin'], errors='coerce', downcast='integer')
# df['categorical_column'] = np.where(df['numerical_column'].isnull(),df['Cabin'], np.nan)
